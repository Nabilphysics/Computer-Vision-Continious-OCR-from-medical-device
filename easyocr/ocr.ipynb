# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import easyocr
reader = easyocr.Reader(['en'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
import urllib.request
import cv2 as cv #Please install with PIP: pip install cv2
import numpy as np

# %%
from PIL import Image

import urllib.request
import io

URL = 'http://192.168.0.108/capture?'

with urllib.request.urlopen(URL) as url:
    f = io.BytesIO(url.read())


img = Image.open(f)
img
#img.show()
#import PIL

#im = PIL.Image.open("chat1.JPG")
#im = imgNp

#out = img.rotate(90)
#im = Image.open(f)
#im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x28F93E68340>

# %%
bounds = reader.readtext(img)
bounds
# Out:
# [([[267, 47], [339, 47], [339, 61], [267, 61]],
#   'Rhanona',
#   0.054058598051481034),
#  ([[143, 51], [490, 51], [490, 188], [143, 188]], 'ZERO', 0.999842643737793),
#  ([[285, 189], [335, 189], [335, 225], [285, 225]], 'TO', 0.603493477717168),
#  ([[163, 219], [472, 219], [472, 357], [163, 357]], 'ONE', 0.9996068790099976),
#  ([[181, 369], [432, 369], [432, 420], [181, 420]],
#   'NOTES ON STARTUPS,',
#   0.9516876319904181),
#  ([[289, 415], [315, 415], [315, 433], [289, 433]], 'OR', 0.8837760441263703),
#  ([[150, 428], [462, 428], [462, 480], [150, 480]],
#   'How TO BUILD THE FUTURE',
#   0.3422709636905663)]

# %%
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(img, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x28F93E68340>

# %%
len(bounds)
# Out:
# 7

# %%
for i in bounds:
    if i[2]>0.1:
     print(i[1], '      ',i[2])
# Out:
# ZERO        0.999842643737793
# TO        0.603493477717168
# ONE        0.9996068790099976
# NOTES ON STARTUPS,        0.9516876319904181
# OR        0.8837760441263703
# How TO BUILD THE FUTURE        0.3422709636905663
