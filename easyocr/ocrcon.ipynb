# ########## Started ###########
# Pu ADDUL
# KALam
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALAM
# VTONRAI
# ########## END ###########
# ########## Started ###########
# apa abiul
# KALa
# VTONRAI
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALaM
# DONRAI
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALAM
# FONIAI
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALAM
# TONII
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALaM
# TONTAI
# ########## END ###########
# ########## Started ###########
# apu abiul
# KALam
# TONRA
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALaM
# IONIUI
# ########## END ###########
# ########## Started ###########
# Ap# abduL
# KALAm
# ONICAI
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALAm
# TONICAI
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALam
# TONICAI
# ########## END ###########
# ########## Started ###########
# apu abdul
# KALam
# RONIAT
# ########## END ###########
# ########## Started ###########
# Ap# abiuL
# KALam
# VRONRNI
# ########## END ###########
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-42bd280b8342> in <module>
#      28     img
#      29
# ---> 30     bounds = reader.readtext(img)
#      31     bounds
#      32
#
# C:\ProgramData\Anaconda3\lib\site-packages\easyocr\easyocr.py in readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, output_format)
#     391         # get the 1st result from hor & free list as self.detect returns a list of depth 3
#     392         horizontal_list, free_list = horizontal_list[0], free_list[0]
# --> 393         result = self.recognize(img_cv_grey, horizontal_list, free_list,\
#     394                                 decoder, beamWidth, batch_size,\
#     395                                 workers, allowlist, blocklist, detail, rotation_info,\
#
# C:\ProgramData\Anaconda3\lib\site-packages\easyocr\easyocr.py in recognize(self, img_cv_grey, horizontal_list, free_list, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, contrast_ths, adjust_contrast, filter_ths, y_ths, x_ths, reformat, output_format)
#     324                 f_list = []
#     325                 image_list, max_width = get_image_list(h_list, f_list, img_cv_grey, model_height = imgH)
# --> 326                 result0 = get_text(self.character, imgH, int(max_width), self.recognizer, self.converter, image_list,\
#     327                               ignore_char, decoder, beamWidth, batch_size, contrast_ths, adjust_contrast, filter_ths,\
#     328                               workers, self.device)
#
# C:\ProgramData\Anaconda3\lib\site-packages\easyocr\recognition.py in get_text(character, imgH, imgW, recognizer, converter, image_list, ignore_char, decoder, beamWidth, batch_size, contrast_ths, adjust_contrast, filter_ths, workers, device)
#     204
#     205     # predict first round
# --> 206     result1 = recognizer_predict(recognizer, converter, test_loader,batch_max_length,\
#     207                                  ignore_idx, char_group_idx, decoder, beamWidth, device = device)
#     208
#
# C:\ProgramData\Anaconda3\lib\site-packages\easyocr\recognition.py in recognizer_predict(model, converter, test_loader, batch_max_length, ignore_idx, char_group_idx, decoder, beamWidth, device)
#     109             text_for_pred = torch.LongTensor(batch_size, batch_max_length + 1).fill_(0).to(device)
#     110
# --> 111             preds = model(image, text_for_pred)
#     112
#     113             # Select max probabilty (greedy decoding) then decode index to character
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\easyocr\model\vgg_model.py in forward(self, input, text)
#      23     def forward(self, input, text):
#      24         """ Feature extraction stage """
# ---> 25         visual_feature = self.FeatureExtraction(input)
#      26         visual_feature = self.AdaptiveAvgPool(visual_feature.permute(0, 3, 1, 2))
#      27         visual_feature = visual_feature.squeeze(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\easyocr\model\modules.py in forward(self, input)
#     115
#     116     def forward(self, input):
# --> 117         return self.ConvNet(input)
#     118
#     119 class ResNet_FeatureExtractor(nn.Module):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\activation.py in forward(self, input)
#     100
#     101     def forward(self, input: Tensor) -> Tensor:
# --> 102         return F.relu(input, inplace=self.inplace)
#     103
#     104     def extra_repr(self) -> str:
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in relu(input, inplace)
#    1294         return handle_torch_function(relu, (input,), input, inplace=inplace)
#    1295     if inplace:
# -> 1296         result = torch.relu_(input)
#    1297     else:
#    1298         result = torch.relu(input)
#
# KeyboardInterrupt:
